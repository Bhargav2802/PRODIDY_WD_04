# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhargav2802/PRODIDY_WD_04/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sklearn as skl
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans, DBSCAN, MeanShift
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv("sales.csv")
df
corr = df[["SALES"]].corr()
print(corr)
# Out:
#        SALES
# SALES    1.0

# %%
df.dropna()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10          10223               37     100.00                1  3965.66
# 21          10361               20      72.55               13  1451.00
# 40          10270               21     100.00                9  4905.39
# 47          10347               30     100.00                1  3944.70
# 51          10391               24     100.00                4  2416.56
# ...           ...              ...        ...              ...      ...
# 2667        10120               43      76.00               14  3268.00
# 2673        10223               26      67.20               15  1747.20
# 2685        10361               44     100.00               10  5001.92
# 2764        10361               35     100.00               11  4277.35
# 2791        10361               23      95.20               12  2189.60
#
#             ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
print(df.head())
print(df.tail())
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
print(df.describe())

plt.figure(figsize=(5,10))
plt.pie(df["SALES"])
plt.show()
df

sortvalues = df.sort_values(by="QUANTITYORDERED", ascending = False)
sortvalues

df["sum"] = (df["SALES"] / df["ORDERNUMBER"])*100
print(df["sum"])
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
names = ["Bhargav","Rahul","Dhruvi"]
age = [21,15,30]

plt.bar(names,age)
plt.title("Names and Age")
plt.xlabel("Age")
plt.ylabel("Names")
plt.show()

plt.plot(age)
plt.show()

# %%
plt.hist(age, color="red", bins=25)
plt.title("Ages")
plt.show()

# %%
a = [10,25,35,14,50]
b = [5,4,3,2,1]

plt.scatter(a,b, color="purple")
plt.title("Examples")
plt.show()

# %%
x = [10,30,60,99]
y = [50,28,51,8]
y1 = [26,29,88,64]
font={'color':'green','size':'20'}
explode = [10]

plt.pie(x, labels=x, autopct="%1.1f%%", startangle=90)
plt.title("Sample pie chart")
plt.legend("Nu")
plt.show()

plt.figure()
plt.plot(x, color="red", marker="D", linestyle="dotted", linewidth="10")
plt.plot(x, y, color="yellow", marker=".", linestyle="-")
plt.plot(x, y1, color="green", marker="X", linestyle="--",ms=10,mec="b",mfc="y")
plt.title("line chart",fontdict=font, loc='left')
plt.show()

# %%
c = [10.20,20,30,30,30,40,40,40,40,50]

plt.hist(c, bins=9)
plt.title("Example")
# Out:
# Text(0.5, 1.0, 'Example')

# %%
X = np.array([1,2,3,4,5]).reshape(-1, 1)
y = np.array([10,20,30,40])

# %%
data = pd.DataFrame({
    "d":[1,2,3,10,11,12],
    "e":[2,3,4,10,11,12]
})

kmeans = KMeans(n_clusters=2)
data["cluster"] = kmeans.fit_predict(data)

plt.scatter(data["d"], data["e"], c=data["cluster"])

# %%
emp = pd.DataFrame({
    "s":[50,60,70,80],
    "w":[10,20,30,40]
        })

kmeans = KMeans(n_clusters = 4)
emp["cluster"] = kmeans.fit_predict(emp)

plt.scatter(emp["s"], emp["w"], c=emp["cluster"])
plt.show()

# %%
x = np.array([1,2,3,4,5]).reshape(-1,1)
y = np.array([1,3,5,7,9])

print(df.shape)
# Out:
# (2823, 26)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)

model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(x_test)
print(pred)
# Out:
# [1.]

# %%
x = df[["ORDERNUMBER"]]
y = df["SALES"]

x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.2)

model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(x_test)
print(pred)
# Out:
# [3602.87457262 3593.40329378 3597.8232239  3558.04385277 3652.75664118
#  3511.95029574 3487.95638934 3631.28840914 3637.60259503 3618.02861876
#  3494.27057524 3588.35194506 3615.5029444  3536.57562073 3661.59650143
#  3594.66613095 3564.98945725 3673.59345463 3649.59954823 3472.8023432
#  3579.51208481 3474.06518038 3599.71747967 3499.32192395 3472.8023432
#  3635.70833927 3619.92287453 3598.45464249 3639.4968508  3499.95334254
#  3656.54515272 3539.73271368 3494.27057524 3670.43636168 3564.98945725
#  3479.74794768 3585.19485211 3562.46378289 3534.04994637 3584.56343352
#  3579.51208481 3482.90504063 3486.06213358 3554.25534123 3641.39110657
#  3539.73271368 3472.17092461 3564.35803866 3540.99555085 3640.12826939
#  3574.46073609 3617.39720017 3642.02252516 3607.29450274 3506.89894703
#  3471.53950602 3582.66917776 3490.4820637  3527.73576048 3637.60259503
#  3494.90199383 3511.31887715 3535.31278355 3550.4668297  3571.30364315
# ...

# %%
print(y_test.values)
print(x_test)
# Out:
# [ 3535.95  2234.4   4508.    2397.45  4042.08  4608.    3853.6   3559.64
#    834.67  9558.8   2851.54  4567.98  2223.52  4076.19  4509.12  7947.31
#   3092.6   2702.04  4143.6   3073.26  2353.2   2821.66  3323.84  3469.5
#   4774.86  2317.44  1864.8   4641.48  8470.14  5375.4   2577.6   1476.28
#   1254.83  7695.6   2832.    2780.58  4093.    2568.24  8291.04  1693.56
#   3163.65  1536.57  2559.6   1981.65  3036.    1339.8   3983.5   1774.22
#   3604.23  2431.75  4645.72  2424.    4328.6   3403.08  3996.4   1705.92
#   4750.8   3273.9   2491.86  5018.4   5500.44  1668.4   3053.28  4716.23
#   4142.16  6446.7   2969.46  2832.     891.03  2142.14  1757.91  2163.72
#   1320.75  3854.24  3427.2   4392.12  1921.92  3288.78  2351.36  2185.15
#   3188.12  5069.66  2055.74  3716.88  1939.3   1668.25  3684.67  2183.25
#   2314.4   1892.1   5348.5   2624.64  3920.88  3525.6   1013.48  2948.16
#   4724.91  2310.88   856.52  4183.    5105.14  1824.    3003.    4191.25
# ...

# %%
x = df[["ORDERNUMBER"]]
y = df["QTR_ID"]

x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2)

model = KMeans()
model.fit(x_train,y_train)

pred = model.predict(x_test)
print("Prediction: ", pred)
print(y_test.values)
print(x_test)
print(x_train)
print(model.labels_)
acc = accuracy_score(y_test.astype(int),pred)
print(acc)
# Out:
# Prediction:  [0 7 6 6 6 0 6 1 7 2 1 6 3 0 5 0 2 1 2 1 5 5 1 4 3 2 5 6 0 0 5 0 7 2 2 7 0
#  7 7 1 6 3 3 5 0 0 3 2 0 4 0 3 4 0 6 1 2 0 5 6 5 1 6 6 2 1 4 0 1 1 4 0 7 7
#  1 2 5 0 7 3 3 2 3 2 2 2 6 0 7 2 5 7 1 2 2 1 3 4 5 6 5 5 0 6 5 5 0 7 5 1 1
#  0 2 1 5 1 3 7 1 7 4 0 2 5 1 3 6 1 6 7 7 1 0 1 5 7 2 2 7 0 2 0 1 0 2 1 2 5
#  2 5 7 7 1 5 3 2 3 2 1 5 3 4 4 7 6 6 7 0 6 4 1 4 2 3 7 7 1 6 5 5 1 1 3 5 7
#  3 6 5 5 3 0 4 0 1 1 2 1 7 6 6 1 4 7 4 5 5 7 5 3 7 0 3 0 5 4 4 5 2 1 2 3 4
#  1 6 1 3 5 6 2 4 5 1 1 4 4 4 1 7 3 7 0 5 2 2 6 7 5 0 4 3 0 1 1 2 1 0 3 7 5
#  2 3 2 5 4 6 7 2 5 0 0 1 6 2 2 4 2 4 5 1 3 4 1 0 1 2 6 5 6 0 6 6 6 0 6 6 1
#  7 5 5 6 5 4 6 4 4 1 6 3 4 6 6 5 7 1 0 6 6 0 6 5 5 1 1 7 0 1 5 4 7 0 6 1 1
#  0 2 7 0 1 4 3 7 5 1 5 5 6 2 5 4 7 2 0 5 5 2 1 2 1 6 0 2 6 5 1 3 0 5 2 6 2
#  5 1 4 4 4 4 0 5 5 2 2 5 7 2 3 3 0 3 3 7 1 2 7 5 1 0 0 4 3 6 1 2 0 5 5 5 3
#  4 7 6 3 5 4 7 7 4 4 7 6 3 3 0 6 1 2 1 0 4 3 4 2 0 6 2 2 5 4 7 6 0 6 7 7 4
# ...

# %%
df["QTR_ID"] = df["QTR_ID"] * 1.1
df["QTR_ID"]
# Out:
# 0       1.21
# 1       2.42
# 2       3.63
# 3       3.63
# 4       4.84
#         ...
# 2818    4.84
# 2819    1.21
# 2820    1.21
# 2821    1.21
# 2822    2.42
# Name: QTR_ID, Length: 2823, dtype: float64

# %%
from sklearn.cluster import KMeans

X = [[1,3],[2,6],[3,4]]

model = KMeans(n_clusters=3)
model.fit(X)

print(model.labels_)
# Out:
# [1 0 2]

# %%
x = [[1,2],[2,1],[3,1],[1,3],[1,4],[4,1]]

model = KMeans(n_clusters=3)
model.fit(x)

pred = model.predict(x)
print(pred)
print(model.labels_)
# Out:
# [2 0 0 1 1 0]
# [2 0 0 1 1 0]

# %%
x = [[1,2],[2,1],[3,1],[1,3],[1,4],[4,1]]

z = linkage(x, method="ward")
dendrogram(z)
plt.show()

# %%
x = [[1,2],[2,1],[3,1],[1,3],[1,4],[4,9]]

a = linkage(x, method="ward")
dendrogram(a)
plt.show()

# %%
x = [[1,2],[2,1],[3,1],[1,3],[1,6],[8,1]]

z = linkage(x, method="ward")
dendrogram(z)
plt.show()

# %%
x = [[1],[2],[3],[4],[5]]

z = linkage(x, method = "ward")

dendrogram(z)
plt.show()

# %%
x = [[1,2],[2,1],[3,1],[1,3],[1,6],[8,1]]

model = DBSCAN(eps = 2, min_samples = 3)
pred = model.fit_predict(x)

print(pred)
# Out:
# [ 0  0  0  0 -1 -1]

# %%
x = [[1],[2],[3],[4],[5]]

model = DBSCAN(eps=2, min_samples=3)
pred = model.fit_predict(x)

print(pred)
# Out:
# [0 0 0 0 0]

# %%
x = np.array([1,2,3,4,5]).reshape(-1,1)
y = np.array([1,3,5,7,9])

x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2)

model = LinearRegression()
model.fit(x,y)

pred = model.predict(x_test)
print(pred)
# Out:
# [9.]

# %%
x = [[1],[2],[3],[4],[5]]

model = DBSCAN(eps=2,min_samples=3)

pred = model.fit_predict(x)
print(pred)
# Out:
# [0 0 0 0 0]

# %%
x = [[1],[2],[3],[4],[5]]

model = MeanShift()
model.fit(x)

pred = model.predict(x)
print(pred)
# Out:
# [4 3 2 1 0]

# %%
sns.scatterplot(x="ORDERNUMBER", y="SALES", data=df, color="red", marker=">")
plt.grid(True)
plt.title("ORDERNUMBER VS SALES", color="red")
plt.show()

# %%
sns.histplot(x="ORDERNUMBER", y="SALES", data=df)
# Out:
# <Axes: xlabel='ORDERNUMBER', ylabel='SALES'>

# %%
sns.boxplot(df["ORDERNUMBER"])
# Out:
# <Axes: ylabel='ORDERNUMBER'>

# %%
corr = df.corr(numeric_only=True)

sns.heatmap(corr, annot=True,)
# Out:
# <Axes: >

# %%
sns.lineplot(df["SALES"])
# Out:
# <Axes: ylabel='SALES'>

# %%
sns.regplot(x="SALES", y = "ORDERNUMBER", data=df, color="purple")
plt.legend(labels)
